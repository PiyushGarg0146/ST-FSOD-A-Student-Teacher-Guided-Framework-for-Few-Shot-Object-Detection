# %%
import matplotlib.pyplot as plt

# Example steps indices
steps_epoch1 = [
  20, 40, 60, 80, 100, 120, 140, 160, 180, 200,
  220, 240, 260, 280, 300, 320, 340, 360, 380, 400,
  420, 440, 460, 480, 500, 520, 540, 560, 580, 600,
  620, 640, 660, 680, 700, 720, 740, 760, 780, 800,
  820, 840, 860, 880, 900, 920, 940, 960, 980, 1000,
  1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200,
  1220, 1240, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400,
  1420, 1440, 1460, 1480, 1500, 1520, 1540, 1560, 1580, 1600,
  1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800,
  1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000,
  2020, 2040, 2060, 2080, 2100, 2120, 2140, 2160, 2180, 2200,
  2220, 2240, 2260, 2280, 2300, 2320, 2340, 2360, 2380, 2400,
  2420, 2440, 2460, 2480, 2500, 2520, 2540, 2560, 2580, 2600,
  2620, 2640, 2660, 2680, 2700, 2720, 2740, 2760, 2780, 2800,
  2820, 2840
]

loss_epoch1 = [
  6.1750, 3.7940, 3.2865, 3.4372, 5.2611, 4.0773, 5.2829, 3.4722,
  4.4689, 2.8503, 3.8077, 4.0061, 4.2132, 4.0910, 2.7909, 3.1762,
  3.1539, 3.3482, 2.8806, 3.6317, 2.6545, 3.6472, 2.7679, 2.7803,
  2.5941, 4.0626, 3.1756, 3.7602, 3.1639, 4.3708, 3.0418, 2.3274,
  4.1691, 3.3924, 2.7650, 3.1869, 5.0181, 3.4937, 5.5681, 3.5819,
  3.0179, 5.2873, 5.4156, 4.4204, 5.1163, 4.4302, 3.5444, 5.2273,
  4.6041, 4.1679, 4.6089, 4.3571, 4.9439, 4.5071, 4.1067, 3.9577,
  4.5983, 4.4120, 4.0330, 3.6478, 5.1369, 4.9882, 4.7227, 3.7520,
  3.8022, 4.8975, 4.5980, 3.0852, 4.2829, 4.4706, 3.6090, 3.3826,
  3.4323, 3.3015, 5.1699, 3.6024, 3.7244, 2.8460, 3.2788, 3.7376,
  4.5879, 2.8950, 3.6146, 6.1656, 4.9403, 3.4129, 2.4732, 3.9462,
  4.9182, 6.1123, 2.5357, 3.6887, 5.0137, 3.3677, 3.5661, 3.1912,
  3.4745, 4.1337, 4.9403, 3.1506, 4.0976, 3.4240, 3.6372, 4.3676,
  3.0410, 4.1238, 3.8192, 4.1994, 2.7863, 2.9266, 4.1207, 4.2685,
  4.3059, 2.5183, 4.0644, 4.0648, 3.6332, 4.7579, 3.0275, 2.8982,
  4.5561, 4.3087, 3.8499, 3.5617, 2.3782, 2.5529, 4.0630, 4.1390,
  3.0070, 4.0466, 2.5880, 3.6005, 3.0057, 3.1884, 3.1744, 1.9947,
  2.5347, 4.3621, 4.2609, 3.0702, 4.1636
]

det_epoch1 = [
  5.5693, 3.0688, 2.7807, 2.6753, 4.6060, 3.2544, 4.4689, 2.7009,
  3.7301, 2.0991, 2.9090, 3.1984, 3.4449, 3.3608, 2.0707, 2.3554,
  2.2477, 2.4682, 2.0493, 2.9792, 1.8308, 2.7772, 1.8891, 1.8380,
  1.6895, 3.0661, 2.3262, 2.6897, 2.0653, 3.4939, 2.1447, 1.3695,
  3.1404, 2.6473, 1.7689, 2.2569, 4.0261, 2.4701, 4.7294, 2.7012,
  1.8359, 4.3058, 4.3712, 3.5465, 4.1350, 3.3872, 2.6284, 4.3265,
  3.7489, 3.0887, 3.5013, 3.4235, 3.8903, 3.6737, 2.9422, 2.7658,
  3.5921, 3.4194, 3.0573, 2.6806, 4.0897, 3.9894, 3.6348, 2.7759,
  2.7968, 4.0705, 3.7488, 2.2270, 3.3137, 3.5134, 2.5949, 2.4759,
  2.5790, 2.3395, 4.2479, 2.7435, 2.7026, 2.0313, 2.2112, 2.7979,
  3.6526, 1.9726, 2.8306, 5.2608, 4.0492, 2.4135, 1.7730, 3.1150,
  4.0847, 5.0623, 1.8360, 2.8772, 4.1558, 2.4271, 2.5234, 2.3921,
  2.5620, 3.2053, 3.9888, 2.2894, 3.2982, 2.4214, 2.6276, 3.4448,
  2.1396, 3.1587, 2.7170, 3.5187, 1.8761, 2.0592, 3.0587, 3.1970,
  3.4002, 1.7117, 3.1710, 3.1190, 2.8393, 3.9639, 2.1876, 2.2562,
  3.6226, 3.3927, 3.0179, 2.6517, 1.5380, 1.6746, 3.0298, 3.3285,
  2.0963, 2.9170, 1.6578, 2.7408, 2.0836, 2.3860, 2.2869, 1.2934,
  1.5900, 3.5385, 3.3499, 1.9707, 3.2328
]

kd_epoch1 = [
  0.1077, 0.1377, 0.1211, 0.1203, 0.1192, 0.0964, 0.1233, 0.1357,
  0.1551, 0.1878, 0.1976, 0.2053, 0.1745, 0.2225, 0.1876, 0.2072,
  0.3216, 0.2797, 0.3389, 0.3907, 0.3946, 0.4558, 0.3758, 0.3711,
  0.5475, 0.5586, 0.4158, 0.5202, 0.4620, 0.4608, 0.5643, 0.5905,
  0.5523, 0.5295, 0.6361, 0.5879, 0.4158, 0.5465, 0.5058, 0.5355,
  0.7362, 0.4479, 0.5724, 0.6648, 0.6059, 0.6084, 0.6097, 0.4793,
  0.5892, 0.6014, 0.5973, 0.6295, 0.5842, 0.5066, 0.6209, 0.6229,
  0.6174, 0.5912, 0.5896, 0.6496, 0.6102, 0.5391, 0.5868, 0.6422,
  0.5917, 0.6147, 0.5239, 0.6238, 0.5896, 0.6016, 0.5867, 0.5387,
  0.5674, 0.6005, 0.5967, 0.6036, 0.4972, 0.6387, 0.6270, 0.6201,
  0.5966, 0.6079, 0.4886, 0.5441, 0.6495, 0.5813, 0.5810, 0.4932,
  0.5185, 0.6137, 0.6335, 0.5967, 0.6449, 0.6481, 0.5798,
  0.6575, 0.6345, 0.5843, 0.6554, 0.4929, 0.5703, 0.5789, 0.5244,
  0.4923, 0.6533, 0.5328, 0.5731, 0.5353, 0.6058, 0.7121, 0.6565,
  0.5938, 0.5817, 0.6626, 0.5716, 0.5914, 0.6602, 0.6303, 0.6027,
  0.5825, 0.6090, 0.6229, 0.5332, 0.6125, 0.6082, 0.5785, 0.6560,
  0.5446, 0.5941, 0.6612, 0.6748, 0.5422, 0.6453, 0.6251, 0.5786,
  0.5662, 0.6838, 0.5766, 0.5699, 0.6429, 0.6604
]

# Find the minimal length
min_len = min(len(steps), len(loss), len(det), len(kd))
print("Using first", min_len, "data points")

# Trim all arrays to this common length
steps_trim = steps[:min_len]
loss_trim  = loss[:min_len]
det_trim   = det[:min_len]
kd_trim    = kd[:min_len]

# Plot Loss
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, loss_trim,
    linestyle='-',      # solid line
    marker='o',         # circle markers
    markersize=4,       # marker size
    linewidth=1,        # line width
    color='blue',
    label='Loss'
)
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot Det
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, det_trim,
    linestyle='-', marker='o', markersize=4, linewidth=1,
    color='green', label='Det'
)
plt.xlabel('Step')
plt.ylabel('Det Value')
plt.title('Det vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot KD
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, kd_trim,
    linestyle='-', marker='o', markersize=4, linewidth=1,
    color='red', label='KD'
)
plt.xlabel('Step')
plt.ylabel('KD Value')
plt.title('KD vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Combined plot
plt.figure(figsize=(8, 6))
plt.plot(steps_trim, loss_trim, linestyle='-', marker='o', markersize=4, linewidth=1, color='blue',  label='Loss')
plt.plot(steps_trim, det_trim,  linestyle='-', marker='o', markersize=4, linewidth=1, color='green', label='Det')
plt.plot(steps_trim, kd_trim,   linestyle='-', marker='o', markersize=4, linewidth=1, color='red',   label='KD')
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Loss, Det and KD vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Using first 138 data points

# %% [markdown]
# epoch 2 result

# %%
import matplotlib.pyplot as plt

# ---- paste your arrays here ----
steps = [
  20, 40, 60, 80, 100, 120, 140, 160, 180, 200,
  220, 240, 260, 280, 300, 320, 340, 360, 380, 400,
  420, 440, 460, 480, 500, 520, 540, 560, 580, 600,
  620, 640, 660, 680, 700, 720, 740, 760, 780, 800,
  820, 840, 860, 880, 900, 920, 940, 960, 980, 1000,
  1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200,
  1220, 1240, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400,
  1420, 1440, 1460, 1480, 1500, 1520, 1540, 1560, 1580, 1600,
  1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800,
  1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000,
  2020, 2040, 2060, 2080, 2100, 2120, 2140, 2160, 2180, 2200,
  2220, 2240, 2260, 2280, 2300, 2320, 2340, 2360, 2380, 2400,
  2420, 2440, 2460, 2480, 2500, 2520, 2540, 2560, 2580, 2600,
  2620, 2640, 2660, 2680, 2700, 2720, 2740, 2760, 2780, 2800,
  2820, 2840
]

loss = [
  4.1352, 3.4669, 2.8926, 2.6517, 4.0282, 2.4158, 4.3681, 2.5966,
  2.9052, 3.1500, 6.4165, 4.0432, 5.2770, 3.8120, 3.1341, 3.0705,
  3.2901, 3.4828, 4.3376, 3.7110, 4.8961, 3.3968, 2.7598, 4.6636,
  4.6055, 3.1305, 4.0711, 2.5666, 4.5062, 4.4949, 3.4564, 3.9463,
  4.1173, 3.6046, 3.1247, 3.7127, 3.8432, 3.2458, 2.7775, 4.7436,
  4.3036, 2.3781, 4.1675, 4.3923, 3.0484, 3.9295, 3.2544, 3.1590,
  3.4635, 4.0041, 2.9190, 2.1398, 4.9186, 4.3914, 3.4713, 3.1246,
  2.2472, 4.6940, 5.3539, 3.7359, 3.1819, 4.2392, 5.4499, 3.9384,
  4.0719, 4.3176, 4.9128, 5.3448, 5.4418, 4.4070, 3.7751, 4.6637,
  6.1452, 4.2252, 3.7464, 4.6600, 3.1710, 4.7823, 4.3030, 3.0944,
  4.0408, 3.3886, 5.5898, 3.9595, 3.6185, 4.0936, 2.5327, 2.5935,
  3.6147, 3.0710, 4.1836, 2.9780, 3.9445, 4.9470, 2.7131, 4.0356,
  3.8924, 2.5312, 4.1383, 4.8491, 2.6733, 2.4118, 6.0847, 2.9189,
  2.0734, 2.9403, 3.1818, 3.4942, 3.6181, 3.7331, 2.4564, 5.4544,
  3.3066, 4.5704, 2.7526, 3.2231, 3.5607, 2.8550, 4.5165, 3.6711,
  2.6285, 3.5232, 3.0249, 3.6015, 4.3982, 4.3756, 3.4737, 3.2165,
  2.4129, 2.9135, 3.9062, 3.0820, 2.4285, 3.9380, 2.0083, 3.0416,
  2.8322, 3.2851, 4.1623, 3.1071, 4.6598, 3.6049
]

det = [
  3.3465, 2.5105, 2.0176, 1.9459, 3.2501, 1.6483, 3.4931, 1.6258,
  2.0056, 2.3887, 5.4844, 3.0998, 4.3182, 2.8764, 2.2008, 2.1272,
  2.3331, 2.6442, 3.5576, 2.8402, 4.1148, 2.6475, 2.0549, 3.8727,
  3.8969, 2.1567, 2.9549, 1.7719, 3.7694, 3.7383, 2.7334, 2.9553,
  3.0582, 2.8302, 2.1966, 2.7887, 3.1080, 2.3747, 1.8330, 3.8164,
  3.4373, 1.6826, 3.3994, 3.3732, 2.0920, 3.0639, 2.2909, 2.4080,
  2.7417, 3.1520, 2.0558, 1.3238, 4.2170, 3.5945, 2.5336, 2.3774,
  1.3353, 4.0433, 4.5634, 3.0579, 2.3674, 3.3516, 4.6231, 3.0440,
  3.1746, 3.5240, 3.9718, 4.5173, 4.5870, 3.5374, 3.1507, 3.9147,
  5.2740, 3.1530, 3.0968, 3.8452, 2.2854, 4.0449, 3.4288, 2.3604,
  3.2026, 2.4173, 4.6411, 3.1771, 2.8661, 3.2583, 1.6338, 1.7592,
  2.7900, 2.3089, 3.4368, 2.2049, 3.0437, 4.0352, 1.8127, 2.9449,
  3.0665, 1.6693, 3.0991, 4.0349, 1.8046, 1.7165, 5.3082, 2.0165,
  1.2395, 2.0679, 2.4401, 2.7194, 2.7563, 2.7692, 1.5843, 4.4913,
  2.4288, 3.7141, 1.6300, 2.3766, 2.7424, 1.9866, 3.7316, 2.8667,
  1.8068, 2.5641, 2.1224, 2.5780, 3.6287, 3.6296, 2.6659, 2.4372,
  1.7180, 2.0457, 2.9841, 2.4148, 1.5434, 3.1972, 1.2307, 2.1534,
  1.8047, 2.3344, 3.2152, 2.3397, 3.9177, 3.0199
]

kd = [
  0.6172, 0.6479, 0.6631, 0.6257, 0.5024, 0.6430, 0.5920, 0.6474,
  0.6814, 0.5964, 0.5728, 0.5477, 0.5257, 0.5987, 0.6239, 0.6302,
  0.6115, 0.6699, 0.6098, 0.6356, 0.6089, 0.5539, 0.5411, 0.5388,
  0.5088, 0.4941, 0.6249, 0.6302, 0.5493, 0.6165, 0.5709, 0.6553,
  0.6110, 0.5592, 0.5757, 0.5723, 0.5812, 0.5639, 0.6335, 0.6062,
  0.5477, 0.5345, 0.5851, 0.6153, 0.6493, 0.5170, 0.6236, 0.5703,
  0.7149, 0.6467, 0.6746, 0.6078, 0.5814, 0.5806, 0.5694, 0.5975,
  0.6362, 0.5814, 0.4920, 0.5081, 0.6827, 0.6063, 0.5973, 0.6178,
  0.7039, 0.4207, 0.4477, 0.4751, 0.6198, 0.5171, 0.4803, 0.5001,
  0.5609, 0.5510, 0.5205, 0.5402, 0.5681, 0.5687, 0.5640, 0.5844,
  0.5529, 0.6355, 0.5582, 0.5597, 0.5500, 0.6128, 0.5820, 0.5245,
  0.6555, 0.5799, 0.6119, 0.6238, 0.6660, 0.6282, 0.6409, 0.6161,
  0.5488, 0.6051, 0.6159, 0.6067, 0.5991, 0.5498, 0.5823, 0.6324,
  0.5712, 0.5946, 0.5902, 0.5017, 0.5798, 0.6836, 0.5886, 0.5842,
  0.5506, 0.5791, 0.6563, 0.6043, 0.5914, 0.5099, 0.4836, 0.5727,
  0.6451, 0.5427, 0.5284, 0.5981, 0.6222, 0.5794, 0.6569, 0.5947,
  0.5638, 0.5672, 0.6011, 0.6251, 0.6093, 0.4958, 0.6263, 0.6828,
  0.5449, 0.6138, 0.5072, 0.5496, 0.7005, 0.4654
]
# ---- end of arrays ----
min_len = min(len(steps), len(loss), len(det), len(kd))
print("Using first", min_len, "data points")

# Trim all arrays to this common length
steps_trim = steps[:min_len]
loss_trim  = loss[:min_len]
det_trim   = det[:min_len]
kd_trim    = kd[:min_len]

# Plot Loss
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, loss_trim,
    linestyle='-',      # solid line
    marker='o',         # circle markers
    markersize=4,       # marker size
    linewidth=1,        # line width
    color='blue',
    label='Loss'
)
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot Det
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, det_trim,
    linestyle='-', marker='o', markersize=4, linewidth=1,
    color='green', label='Det'
)
plt.xlabel('Step')
plt.ylabel('Det Value')
plt.title('Det vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot KD
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, kd_trim,
    linestyle='-', marker='o', markersize=4, linewidth=1,
    color='red', label='KD'
)
plt.xlabel('Step')
plt.ylabel('KD Value')
plt.title('KD vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Combined plot
plt.figure(figsize=(8, 6))
plt.plot(steps_trim, loss_trim, linestyle='-', marker='o', markersize=4, linewidth=1, color='blue',  label='Loss')
plt.plot(steps_trim, det_trim,  linestyle='-', marker='o', markersize=4, linewidth=1, color='green', label='Det')
plt.plot(steps_trim, kd_trim,   linestyle='-', marker='o', markersize=4, linewidth=1, color='red',   label='KD')
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Loss, Det and KD vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Using first 142 data points

# %%
steps_epoch2 = [
  20, 40, 60, 80, 100, 120, 140, 160, 180, 200,
  220, 240, 260, 280, 300, 320, 340, 360, 380, 400,
  420, 440, 460, 480, 500, 520, 540, 560, 580, 600,
  620, 640, 660, 680, 700, 720, 740, 760, 780, 800,
  820, 840, 860, 880, 900, 920, 940, 960, 980, 1000,
  1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200,
  1220, 1240, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400,
  1420, 1440, 1460, 1480, 1500, 1520, 1540, 1560, 1580, 1600,
  1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800,
  1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000,
  2020, 2040, 2060, 2080, 2100, 2120, 2140, 2160, 2180, 2200,
  2220, 2240, 2260, 2280, 2300, 2320, 2340, 2360, 2380, 2400,
  2420, 2440, 2460, 2480, 2500, 2520, 2540, 2560, 2580, 2600,
  2620, 2640, 2660, 2680, 2700, 2720, 2740, 2760, 2780, 2800,
  2820, 2840
]

loss_epoch2 = [
  4.1352, 3.4669, 2.8926, 2.6517, 4.0282, 2.4158, 4.3681, 2.5966,
  2.9052, 3.1500, 6.4165, 4.0432, 5.2770, 3.8120, 3.1341, 3.0705,
  3.2901, 3.4828, 4.3376, 3.7110, 4.8961, 3.3968, 2.7598, 4.6636,
  4.6055, 3.1305, 4.0711, 2.5666, 4.5062, 4.4949, 3.4564, 3.9463,
  4.1173, 3.6046, 3.1247, 3.7127, 3.8432, 3.2458, 2.7775, 4.7436,
  4.3036, 2.3781, 4.1675, 4.3923, 3.0484, 3.9295, 3.2544, 3.1590,
  3.4635, 4.0041, 2.9190, 2.1398, 4.9186, 4.3914, 3.4713, 3.1246,
  2.2472, 4.6940, 5.3539, 3.7359, 3.1819, 4.2392, 5.4499, 3.9384,
  4.0719, 4.3176, 4.9128, 5.3448, 5.4418, 4.4070, 3.7751, 4.6637,
  6.1452, 4.2252, 3.7464, 4.6600, 3.1710, 4.7823, 4.3030, 3.0944,
  4.0408, 3.3886, 5.5898, 3.9595, 3.6185, 4.0936, 2.5327, 2.5935,
  3.6147, 3.0710, 4.1836, 2.9780, 3.9445, 4.9470, 2.7131, 4.0356,
  3.8924, 2.5312, 4.1383, 4.8491, 2.6733, 2.4118, 6.0847, 2.9189,
  2.0734, 2.9403, 3.1818, 3.4942, 3.6181, 3.7331, 2.4564, 5.4544,
  3.3066, 4.5704, 2.7526, 3.2231, 3.5607, 2.8550, 4.5165, 3.6711,
  2.6285, 3.5232, 3.0249, 3.6015, 4.3982, 4.3756, 3.4737, 3.2165,
  2.4129, 2.9135, 3.9062, 3.0820, 2.4285, 3.9380, 2.0083, 3.0416,
  2.8322, 3.2851, 4.1623, 3.1071, 4.6598, 3.6049
]

det_epoch2 = [
  3.3465, 2.5105, 2.0176, 1.9459, 3.2501, 1.6483, 3.4931, 1.6258,
  2.0056, 2.3887, 5.4844, 3.0998, 4.3182, 2.8764, 2.2008, 2.1272,
  2.3331, 2.6442, 3.5576, 2.8402, 4.1148, 2.6475, 2.0549, 3.8727,
  3.8969, 2.1567, 2.9549, 1.7719, 3.7694, 3.7383, 2.7334, 2.9553,
  3.0582, 2.8302, 2.1966, 2.7887, 3.1080, 2.3747, 1.8330, 3.8164,
  3.4373, 1.6826, 3.3994, 3.3732, 2.0920, 3.0639, 2.2909, 2.4080,
  2.7417, 3.1520, 2.0558, 1.3238, 4.2170, 3.5945, 2.5336, 2.3774,
  1.3353, 4.0433, 4.5634, 3.0579, 2.3674, 3.3516, 4.6231, 3.0440,
  3.1746, 3.5240, 3.9718, 4.5173, 4.5870, 3.5374, 3.1507, 3.9147,
  5.2740, 3.1530, 3.0968, 3.8452, 2.2854, 4.0449, 3.4288, 2.3604,
  3.2026, 2.4173, 4.6411, 3.1771, 2.8661, 3.2583, 1.6338, 1.7592,
  2.7900, 2.3089, 3.4368, 2.2049, 3.0437, 4.0352, 1.8127, 2.9449,
  3.0665, 1.6693, 3.0991, 4.0349, 1.8046, 1.7165, 5.3082, 2.0165,
  1.2395, 2.0679, 2.4401, 2.7194, 2.7563, 2.7692, 1.5843, 4.4913,
  2.4288, 3.7141, 1.6300, 2.3766, 2.7424, 1.9866, 3.7316, 2.8667,
  1.8068, 2.5641, 2.1224, 2.5780, 3.6287, 3.6296, 2.6659, 2.4372,
  1.7180, 2.0457, 2.9841, 2.4148, 1.5434, 3.1972, 1.2307, 2.1534,
  1.8047, 2.3344, 3.2152, 2.3397, 3.9177, 3.0199
]

kd_epoch2 = [
  0.6172, 0.6479, 0.6631, 0.6257, 0.5024, 0.6430, 0.5920, 0.6474,
  0.6814, 0.5964, 0.5728, 0.5477, 0.5257, 0.5987, 0.6239, 0.6302,
  0.6115, 0.6699, 0.6098, 0.6356, 0.6089, 0.5539, 0.5411, 0.5388,
  0.5088, 0.4941, 0.6249, 0.6302, 0.5493, 0.6165, 0.5709, 0.6553,
  0.6110, 0.5592, 0.5757, 0.5723, 0.5812, 0.5639, 0.6335, 0.6062,
  0.5477, 0.5345, 0.5851, 0.6153, 0.6493, 0.5170, 0.6236, 0.5703,
  0.7149, 0.6467, 0.6746, 0.6078, 0.5814, 0.5806, 0.5694, 0.5975,
  0.6362, 0.5814, 0.4920, 0.5081, 0.6827, 0.6063, 0.5973, 0.6178,
  0.7039, 0.4207, 0.4477, 0.4751, 0.6198, 0.5171, 0.4803, 0.5001,
  0.5609, 0.5510, 0.5205, 0.5402, 0.5681, 0.5687, 0.5640, 0.5844,
  0.5529, 0.6355, 0.5582, 0.5597, 0.5500, 0.6128, 0.5820, 0.5245,
  0.6555, 0.5799, 0.6119, 0.6238, 0.6660, 0.6282, 0.6409, 0.6161,
  0.5488, 0.6051, 0.6159, 0.6067, 0.5991, 0.5498, 0.5823, 0.6324,
  0.5712, 0.5946, 0.5902, 0.5017, 0.5798, 0.6836, 0.5886, 0.5842,
  0.5506, 0.5791, 0.6563, 0.6043, 0.5914, 0.5099, 0.4836, 0.5727,
  0.6451, 0.5427, 0.5284, 0.5981, 0.6222, 0.5794, 0.6569, 0.5947,
  0.5638, 0.5672, 0.6011, 0.6251, 0.6093, 0.4958, 0.6263, 0.6828,
  0.5449, 0.6138, 0.5072, 0.5496, 0.7005, 0.4654
]
# Find the minimal length
min_len = min(len(steps), len(loss), len(det), len(kd))
print("Using first", min_len, "data points")

# Trim all arrays to this common length
steps_trim = steps[:min_len]
loss_trim  = loss[:min_len]
det_trim   = det[:min_len]
kd_trim    = kd[:min_len]

# Plot Loss
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, loss_trim,
    linestyle='-',      # solid line
    marker='o',         # circle markers
    markersize=4,       # marker size
    linewidth=1,        # line width
    color='blue',
    label='Loss'
)
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot Det
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, det_trim,
    linestyle='-', marker='o', markersize=4, linewidth=1,
    color='green', label='Det'
)
plt.xlabel('Step')
plt.ylabel('Det Value')
plt.title('Det vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Plot KD
plt.figure(figsize=(8, 6))
plt.plot(
    steps_trim, kd_trim,
    linestyle='-', marker='o', markersize=4, linewidth=1,
    color='red', label='KD'
)
plt.xlabel('Step')
plt.ylabel('KD Value')
plt.title('KD vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Combined plot
plt.figure(figsize=(8, 6))
plt.plot(steps_trim, loss_trim, linestyle='-', marker='o', markersize=4, linewidth=1, color='blue',  label='Loss')
plt.plot(steps_trim, det_trim,  linestyle='-', marker='o', markersize=4, linewidth=1, color='green', label='Det')
plt.plot(steps_trim, kd_trim,   linestyle='-', marker='o', markersize=4, linewidth=1, color='red',   label='KD')
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Loss, Det and KD vs Step')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Using first 138 data points
