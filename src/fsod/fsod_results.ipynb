# %% [markdown]
# graphs of original fsod

# %%
import matplotlib.pyplot as plt

steps = [
    50, 100, 150, 200, 250, 300, 350, 400, 450, 500,
    550, 600, 650, 700, 750, 800, 850, 900, 950, 1000,
    1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500,
    1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000,
    2050, 2100, 2150, 2200, 2250, 2300, 2350, 2400, 2450, 2500,
    2550, 2600, 2650, 2700, 2750, 2800, 2850
]

loss_epoch1 = [
    5.0827, 4.1053, 4.1835, 3.3797, 4.9102, 3.9541, 4.0643, 4.0500, 1.3018, 2.1257,
    2.1506, 2.1438, 1.3437, 2.1941, 3.0260, 3.2636, 2.3815, 2.7485, 2.7729, 4.0074,
    1.8379, 2.1894, 3.2473, 5.4325, 3.4370, 1.7925, 3.5030, 3.9114, 2.6969, 3.6303,
    3.7502, 4.2637, 2.5329, 3.2125, 2.8539, 2.4651, 2.1956, 1.4784, 1.6006, 2.2659,
    3.6574, 3.7114, 1.6655, 3.1476, 3.7712, 1.1526, 2.0302, 2.3730, 2.8935, 3.3962,
    3.4571, 2.8091, 1.4549, 1.4939, 2.8185, 1.7233, 2.4214
]

loss_epoch2 = [
    2.7673, 3.5708, 1.8724, 1.7432, 3.2363, 2.0597, 2.1230, 1.6165, 2.3030, 2.0450,
    2.4410, 3.5190, 4.4846, 2.2201, 2.1883, 3.2448, 1.9487, 3.7942, 2.8671, 1.8796,
    1.4570, 2.7735, 2.2550, 1.7154, 4.3783, 2.2712, 3.3037, 2.3943, 2.8871, 1.7034,
    3.2557, 1.5557, 1.4023, 1.4991, 1.9043, 2.4063, 3.1693, 3.7754, 2.2146, 2.4240,
    2.9128, 1.9066, 2.4859, 3.0150, 1.6115, 2.7161, 3.8418, 3.0986, 2.2077, 4.0177,
    1.8749, 2.3247, 3.6732, 3.1151, 1.6056, 2.7168, 2.3431
]

loss_epoch3 = [
    2.2959, 0.9969, 3.3801, 2.7024, 3.5416, 2.3894, 1.4558, 1.9528, 2.7713, 2.5591,
    2.8569, 2.6237, 3.4517, 4.1084, 1.4149, 2.0102, 3.5431, 3.5470, 2.0179, 2.0472,
    3.6695, 2.1914, 2.9493, 4.5886, 2.8342, 3.2536, 2.0792, 2.7186, 1.2620, 2.0188,
    3.4344, 4.0022, 3.8748, 2.6503, 1.7447, 3.5222, 2.0580, 2.5028, 3.4952, 3.6760,
    2.0928, 3.7649, 1.8206, 3.5205, 1.1444, 2.8964, 2.4482, 2.1199, 2.4015, 3.6903,
    3.3597, 2.1633, 3.1409, 1.0975, 1.4081, 0.9336, 1.7992
]

# Plot for each epoch individually
for epoch_idx, (losses, color) in enumerate([(loss_epoch1, 'blue'),
                                             (loss_epoch2, 'green'),
                                             (loss_epoch3, 'red')], start=1):
    plt.figure(figsize=(10, 4))
    plt.plot(steps, losses, marker='o', linestyle='-', color=color)
    plt.title(f"Training Loss vs. Step — Epoch {epoch_idx}/3")
    plt.xlabel("Step")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

# Step indices (same at each epoch)
steps = [
    50, 100, 150, 200, 250, 300, 350, 400, 450, 500,
    550, 600, 650, 700, 750, 800, 850, 900, 950, 1000,
    1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500,
    1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000,
    2050, 2100, 2150, 2200, 2250, 2300, 2350, 2400, 2450, 2500,
    2550, 2600, 2650, 2700, 2750, 2800, 2850
]

# Loss values you provided
loss_epoch1 = [
    5.0827, 4.1053, 4.1835, 3.3797, 4.9102, 3.9541, 4.0643, 4.0500, 1.3018, 2.1257,
    2.1506, 2.1438, 1.3437, 2.1941, 3.0260, 3.2636, 2.3815, 2.7485, 2.7729, 4.0074,
    1.8379, 2.1894, 3.2473, 5.4325, 3.4370, 1.7925, 3.5030, 3.9114, 2.6969, 3.6303,
    3.7502, 4.2637, 2.5329, 3.2125, 2.8539, 2.4651, 2.1956, 1.4784, 1.6006, 2.2659,
    3.6574, 3.7114, 1.6655, 3.1476, 3.7712, 1.1526, 2.0302, 2.3730, 2.8935, 3.3962,
    3.4571, 2.8091, 1.4549, 1.4939, 2.8185, 1.7233, 2.4214
]

loss_epoch2 = [
    2.7673, 3.5708, 1.8724, 1.7432, 3.2363, 2.0597, 2.1230, 1.6165, 2.3030, 2.0450,
    2.4410, 3.5190, 4.4846, 2.2201, 2.1883, 3.2448, 1.9487, 3.7942, 2.8671, 1.8796,
    1.4570, 2.7735, 2.2550, 1.7154, 4.3783, 2.2712, 3.3037, 2.3943, 2.8871, 1.7034,
    3.2557, 1.5557, 1.4023, 1.4991, 1.9043, 2.4063, 3.1693, 3.7754, 2.2146, 2.4240,
    2.9128, 1.9066, 2.4859, 3.0150, 1.6115, 2.7161, 3.8418, 3.0986, 2.2077, 4.0177,
    1.8749, 2.3247, 3.6732, 3.1151, 1.6056, 2.7168, 2.3431
]

loss_epoch3 = [
    2.2959, 0.9969, 3.3801, 2.7024, 3.5416, 2.3894, 1.4558, 1.9528, 2.7713, 2.5591,
    2.8569, 2.6237, 3.4517, 4.1084, 1.4149, 2.0102, 3.5431, 3.5470, 2.0179, 2.0472,
    3.6695, 2.1914, 2.9493, 4.5886, 2.8342, 3.2536, 2.0792, 2.7186, 1.2620, 2.0188,
    3.4344, 4.0022, 3.8748, 2.6503, 1.7447, 3.5222, 2.0580, 2.5028, 3.4952, 3.6760,
    2.0928, 3.7649, 1.8206, 3.5205, 1.1444, 2.8964, 2.4482, 2.1199, 2.4015, 3.6903,
    3.3597, 2.1633, 3.1409, 1.0975, 1.4081, 0.9336, 1.7992
]

plt.figure(figsize=(12, 6))
plt.plot(steps, loss_epoch1, marker='o', linestyle='-', label='Epoch 1', color='blue')
plt.plot(steps, loss_epoch2, marker='s', linestyle='--', label='Epoch 2', color='green')
plt.plot(steps, loss_epoch3, marker='^', linestyle='-.', label='Epoch 3', color='red')

plt.title("Training Loss vs. Step for Epochs 1-3")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
